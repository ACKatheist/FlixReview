# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('filmes.csv', sep=',')
df['parametros'] = df['listed_in'] + df['title'] + str(df['director']) + str(df['cast']) + str(df['country'])
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['title'] = df['title'].str.lower()
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   dick johnson is dead  Kirsten Johnson
# 1         s2  TV Show          blood & water              NaN
# 2         s3  TV Show              ganglands  Julien Leclercq
# 3         s4  TV Show  jailbirds new orleans              NaN
# 4         s5  TV Show           kota factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 zodiac    David Fincher
# 8803   s8804  TV Show            zombie dumb              NaN
# 8804   s8805    Movie             zombieland  Ruben Fleischer
# 8805   s8806    Movie                   zoom     Peter Hewitt
# 8806   s8807    Movie                 zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
vec = TfidfVectorizer()
tfidf = vec.fit_transform(df['parametros'].apply(lambda x: np.str_(x)))

# %%
sim = cosine_similarity(tfidf)
sim
# Out:
# array([[1.        , 0.59197441, 0.60315366, ..., 0.6642251 , 0.65839066,
#         0.65854574],
#        [0.59197441, 1.        , 0.72173651, ..., 0.63969983, 0.63408082,
#         0.65331072],
#        [0.60315366, 0.72173651, 1.        , ..., 0.65178036, 0.64605523,
#         0.65320742],
#        ...,
#        [0.6642251 , 0.63969983, 0.65178036, ..., 1.        , 0.7114706 ,
#         0.71163819],
#        [0.65839066, 0.63408082, 0.64605523, ..., 0.7114706 , 1.        ,
#         0.71952263],
#        [0.65854574, 0.65331072, 0.65320742, ..., 0.71163819, 0.71952263,
#         1.        ]])

# %%
sim_df = pd.DataFrame(sim, columns=df['title'], index=df['title'])
sim_df
# Out:
# title                  dick johnson is dead  blood & water  ganglands  \
# title
# dick johnson is dead               1.000000       0.591974   0.603154
# blood & water                      0.591974       1.000000   0.721737
# ganglands                          0.603154       0.721737   1.000000
# jailbirds new orleans              0.567634       0.546675   0.556999
# kota factory                       0.573684       0.686473   0.728585
# ...                                     ...            ...        ...
# zodiac                             0.650838       0.638874   0.638644
# zombie dumb                        0.559448       0.649653   0.676134
# zombieland                         0.664225       0.639700   0.651780
# zoom                               0.658391       0.634081   0.646055
# zubaan                             0.658546       0.653311   0.653207
#
# title                  jailbirds new orleans  kota factory  midnight mass  \
# title
# ...

# %%
recomenda_df = pd.DataFrame(sim_df['bosta'].sort_values(ascending=False))
recomenda = pd.DataFrame(recomenda_df.index[1:10])
recomenda['title'][:10].to_string (index = False)
# Out:
# '  zubaan\n   quiet\nkajraare\n  lagaan\n  mirzya\namrapali\n  pitaah\nrangreza\n shikari'
